# %%
import json

# %%
with open('/Users/Melissa/.secret/yelp_api.json') as f: #change the path to match YOUR path!!
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# import the YelpAPI Class
from yelpapi import YelpAPI
# Create an instance with your key
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
help(yelp_api.search_query)
# Out:
# Help on method search_query in module yelpapi.yelpapi:
#
# search_query(**kwargs) method of yelpapi.yelpapi.YelpAPI instance
#     Query the Yelp Search API.
#
#     documentation: https://www.yelp.com/developers/documentation/v3/business_search
#
#     required parameters:
#         * one of either:
#             * location - text specifying a location to search for
#             * latitude and longitude

# %%
# use our yelp_api variable's search_query method to perform our API call
search_results = yelp_api.search_query(location='NY, NY',
                                       term='Pizza')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 16100

# %%
import pandas as pd
biz = pd.DataFrame(search_results['businesses'])
biz.head(2)
# Out:
#                        id                           alias  \
# 0  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
# 1  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
#
#                   name                                          image_url  \
# 0            Juliana's  https://s3-media2.fl.yelpcdn.com/bphoto/NVoLFl...
# 1  Prince Street Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/PfI8oV...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2658
# 1      False  https://www.yelp.com/biz/prince-street-pizza-n...          4933
#
#                                           categories  rating  \
# 0             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 1  {'latitude': 40.72308755605564, 'longitude': -...  [pickup, delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 1     $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
#
#     display_phone     distance
# 0  (718) 596-6700  1289.857286
# 1  (212) 966-4100  2209.311618

# %%
## how many businesses in our results
len(search_results['businesses'])
# Out:
# 20

# %% [markdown]
# The Yelp API will only return a "page" of 20 results at a time.
#
# - If we want to get the next page of results, we will perform another API call, but we will add an additional argument called "offset."
#     - The offset is what # result to use as the FIRST result for the page.
#     - If we had 20 businesses in our first result, we would want to add an offset of 20.

# %%
# add offset to our original api call
search_results = yelp_api.search_query(location='NY, NY',
                                       term='Pizza',
                                       offset = 20)

# %% [markdown]
# Now check the results

# %%
biz20 = pd.DataFrame(search_results['businesses'])
biz20.head(2)
# Out:
#                        id                        alias                name  \
# 0  xxgcU_oFIox_pAmroo9WwA  front-street-pizza-brooklyn  Front Street Pizza
# 1  TWH4MjLtN1fKlF-7n6YXHg        lil-frankies-new-york       Lil Frankie's
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/wRdm4f...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/t0OsEV...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/front-street-pizza-br...           458
# 1  https://www.yelp.com/biz/lil-frankies-new-york...          1457
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
#
#                                         coordinates        transactions price  \
# 0    {'latitude': 40.70244, 'longitude': -73.98943}  [pickup, delivery]     $
# 1  {'latitude': 40.723625, 'longitude': -73.988555}  [pickup, delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': '80 Front St', 'address2': '', 'a...  +17188753700
# 1  {'address1': '19 1st Ave', 'address2': '', 'ad...  +12124204900
#
#     display_phone     distance
# 0  (718) 875-3700   988.843239
# 1  (212) 420-4900  2006.256439

# %% [markdown]
# You should have different results than your original call when you make the offset call.
#
# Now you can combine the results (so far) into one dataframe using pd.concat()

# %%
## concatenate the previous results and new results. 
businesses = pd.concat([biz, biz20],
                      ignore_index=True)
display(businesses.head(3), businesses.tail(3))
# Out:
#                        id                           alias  \
# 0  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
# 1  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 2  WG639VkTjmK5dzydd1BBJA             rubirosa-new-york-2
#
#                   name                                          image_url  \
# 0            Juliana's  https://s3-media2.fl.yelpcdn.com/bphoto/NVoLFl...
# 1  Prince Street Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/PfI8oV...
# 2             Rubirosa  https://s3-media3.fl.yelpcdn.com/bphoto/F65qqO...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2658
# 1      False  https://www.yelp.com/biz/prince-street-pizza-n...          4933
# 2      False  https://www.yelp.com/biz/rubirosa-new-york-2?a...          3049
#
#                                           categories  rating  \
# 0             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 2  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 1  {'latitude': 40.72308755605564, 'longitude': -...  [pickup, delivery]
# 2   {'latitude': 40.722766, 'longitude': -73.996233}            [pickup]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 1     $  {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 2    $$  {'address1': '235 Mulberry St', 'address2': ''...  +12129650500
#
#     display_phone     distance
# 0  (718) 596-6700  1289.857286
# 1  (212) 966-4100  2209.311618
# 2  (212) 965-0500  2268.491950
#                         id                            alias  \
# 37  2FgUndzCT_jJATbmrBDVBg  paulie-gees-slice-shop-brooklyn
# 38  RfFXF-Momn0tLIgh1TZKLw         di-fara-pizza-new-york-2
# 39  l6yVO8l8E5XI9ArgOy5rgw       ltd-pizza-and-bar-new-york
#
#                        name  \
# 37  Paulie Gee's Slice Shop
# 38            Di Fara Pizza
# 39        LTD Pizza and Bar
#
#                                             image_url  is_closed  \
# 37  https://s3-media4.fl.yelpcdn.com/bphoto/x01yyT...      False
# 38  https://s3-media3.fl.yelpcdn.com/bphoto/SaWdpz...      False
# 39  https://s3-media1.fl.yelpcdn.com/bphoto/dU3uTh...      False
#
#                                                   url  review_count  \
# 37  https://www.yelp.com/biz/paulie-gees-slice-sho...           339
# 38  https://www.yelp.com/biz/di-fara-pizza-new-yor...            48
# 39  https://www.yelp.com/biz/ltd-pizza-and-bar-new...             3
#
#                                            categories  rating  \
# 37  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 38             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 39  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     5.0
#
#                                           coordinates  \
# 37      {'latitude': 40.72836, 'longitude': -73.9572}
# 38  {'latitude': 40.706894091267536, 'longitude': ...
# 39  {'latitude': 40.72424964300662, 'longitude': -...
#
#                                   transactions price  \
# 37                                  [delivery]     $
# 38                          [pickup, delivery]   NaN
# 39  [delivery, restaurant_reservation, pickup]   NaN
#
#                                              location         phone  \
# 37  {'address1': '110 Franklin St', 'address2': ''...
# 38  {'address1': '108 South St', 'address2': '', '...  +19173883130
# 39  {'address1': '225 Hudson St', 'address2': None...  +12124191618
#
#      display_phone     distance
# 37                  3016.076927
# 38  (917) 388-3130  1910.297564
# 39  (212) 419-1618  3102.192553
